# %%
import json

# %%
with open('Aeroportos.json') as data_file:    
    data = json.load(data_file)

for key, value in data.items():
    print(data[key]["icao"],data[key]["name"],data[key]["city"],data[key]["iata"],data[key]["lat"],data[key]["lon"],data[key]["elevation"],data[key]["tz"],data[key]["country"])
# Out:
# 00AK Lowell Field Anchor Point  59.94919968 -151.695999146 450 America/Anchorage US
# 00AL Epps Airpark Harvest  34.8647994995 -86.7703018188 820 America/Chicago US
# 00AZ Cordes Airport Cordes  34.3055992126 -112.1650009155 3810 America/Phoenix US
# 00CA Goldstone /Gts/ Airport Barstow  35.3504981995 -116.888000488 3038 America/Los_Angeles US
# 00CL Williams Ag Airport Biggs  39.42718888 -121.76342777 87 America/Los_Angeles US
# 00CO Cass Field Briggsdale  40.6222000122 -104.34400177 4830 America/Denver US
# 00FA Grass Patch Airport Bushnell  28.6455001831 -82.21900177 53 America/New_York US
# 00FL River Oak Airport Okeechobee  27.2308998108 -80.9692001343 35 America/New_York US
# 00GA Lt World Airport Lithonia  33.7675018311 -84.0682983398 700 America/New_York US
# 00ID Delta Shores Airport Clark Fork  48.1453018188 -116.2139968872 2064 America/Los_Angeles US
# 00IL Hammer Airport Polo  41.9784011841 -89.5604019165 840 America/Chicago US
# ...

# %%
import pandas as pd

# %%
with open('Aeroportos.json') as data_file:    
    data = json.load(data_file)

df = pd.DataFrame.from_dict(data, orient='index')

# Salvar o DataFrame em um arquivo CSV
df.to_csv('Aeroportos.csv', index=False)

# %%
#Removendo as colunas que não preciso

df = pd.read_csv(r"C:\Users\brend\OneDrive\Documentos\PYTHON\REPROGRAMA\PROJETO FINAL\Atividade\Aeroportos\Aeroportos.csv")

# Remover colunas indesejadas
colunas_para_remover = ['iata', 'elevation', 'tz']  # Substitua pelos nomes das colunas que você quer remover
df.drop(columns=colunas_para_remover, inplace=True)

# Salvar o DataFrame atualizado em um novo arquivo CSV
df.to_csv(r"C:\Users\brend\OneDrive\Documentos\PYTHON\REPROGRAMA\PROJETO FINAL\Atividade\Aeroportos_atualizado.csv", index=False)
